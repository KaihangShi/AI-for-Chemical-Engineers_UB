# %% [markdown]
# <a href="https://colab.research.google.com/github/KaihangShi/CE-400500-AI-for-Chemical-Engineers/blob/main/CE400500_Lecture_3_Introduction_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CE 400/500: AI for Chemical Engineers - Lecture 3

# %% [markdown]
# This notebook was originally adapted from the [MLCE course](https://edgarsmdn.github.io/MLCE_book/intro.html), reorganized and modified by [Kaihang Shi](https://engineering.buffalo.edu/chemical-biological/people/faculty-directory/core.host.html/content/shared/engineering/chemical-biological/profiles/faculty/shi-kaihang.detail.html) to introduce more background information, hands-on tasks for students, LLM, and LLM-related exercises.

# %% [markdown]
# Google Colab has an interactive Slideshow Mode for transforming notebooks into presentations with live code execution. Simply clicking `View` -> `Start slideshow from beginning` in the top-level menu to use this notebook in class.

# %% [markdown]
# **Goals of this lecture are:**
#
# *   We will learn about the programming language Python as well as [NumPy](https://numpy.org/) and [Matplotlib](https://matplotlib.org/), two fundamental tools for data science and machine learning in Python. (We will introduce other important ML libraries, such as [scikit-learn](https://scikit-learn.org/stable/), as we progress in the semester)
#
# * We will learn how to use the Google's large language model, Gemini, to create, understand, modify, and debug the Python code
#
# * We will learn how to use Gemini to accomplish complex programming tasks that are beyond your current programming skills.
#
#
#
# *Note: The reason we use Gemini is because it is seamlessly integrated in Colab. You could also use ChatGPT, Claude, or GitHub co-pilot (if you are using VS code) to accomplish the same objectives.*

# %% [markdown]
# ## 1. Introduction to Python 🐍

# %% [markdown]
# ### 1.1 What is Python?

# %% [markdown]
# Python's philosophy emphasizes elegance, clarity, and simplicity, making it easy to learn and use for both beginners and experienced programmers.
#
# *   **Python History:** Created by Guido van Rossum during Christmas 1989 to pass the time.
# *   **What Python is:** A high-level programming language used to write applications.
# *   **Comparison to Other Languages:** Compared to low-level languages like C, which are closer to hardware and faster, Python is slower but provides a more complete standard library ("batteries included") and extensive third-party libraries for faster development of applications. Unlike compiled languages like C, Python code is interpreted, making it slower but easier to develop. There are several ways to accelerate Python, such as Cython and parallel computing (Dask).
# *   **What Python is used for:**
#     *  AI & ML!
#     *  Everyday small tools, scripts, data analysis and visualization
#     *  Wrapping programs written in other languages
#     *  Web applications (websites, backend services)
#     *  Used by many large companies and organizations (Google, Yahoo, NASA, YouTube, Instagram, Douban)

# %% [markdown]
# **Most Popular Programming Languages (Worldwide) in 2025**
#
# * The hype around mid-2000 may be due to several reasons: the heavy adoption of Python by Google, release of more robust Python2.4 version, and release of scientific and data libraries such as NumPy.
# * Python is now arguably dominant in AI & ML applications.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1.2 What are Jupyter Notebooks and Google Colab? 🤔

# %% [markdown]
# Notebooks are a great way to mix executable code with rich contents (HTML, images, equations written in LaTeX). Google Colab allows to run notebooks on the cloud for free without any prior installation, while leveraging the power of [GPUs](https://en.wikipedia.org/wiki/Graphics_processing_unit).
#
# *Google Colab Pro version is free to students for a year! (as of August 2025)*

# %% [markdown]
# This document that you are reading is not a static web page, but an interactive environment called a notebook, that lets you write and execute code. Notebooks consist of so-called code cells, blocks of one or more Python instructions. For example, here is a code cell that stores the result of a computation (the number of seconds in a day) in a variable and prints its value:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# print(seconds_in_a_day)
# Out:
# 86400

# %% [markdown]
# Click on the "play" button to execute the cell. You should be able to see the result. Alternatively, you can also execute the cell by pressing `Shift + Enter` if you are on Windows/Linux or `Command + Enter` if you are on a Mac.

# %% [markdown]
# Variables that you defined in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Note that the order of execution is important. For instance, if we do not run the cell storing `seconds_in_a_day` beforehand, the above cell will raise an error, as it depends on this variable. To make sure that you run all the cells in the correct order, you can also click on `Runtime` in the top-level menu, then `Run all`.

# %% [markdown]
# ### 1.3 Exercise - code cells ❗❗
#
# Add a code cell below this cell:
#
# 1.   Click on this cell
# 2.   Click on `+ Code`
# 3.   In the new cell, compute the number of seconds in a year by reusing the variable `seconds_in_a_day`. Run the new cell.

# %% [markdown]
# ## 2. Google's LLM - Gemini 🤖

# %% [markdown]
# Gemini is a family of multimodal large language models (LLMs) from Google, designed to natively understand and operate across text, code, images, audio, and video. It's integrated across Google's ecosystem, including the Gemini conversational AI (formerly Bard) and Workspace apps, giving it access to real-time information.
#
# Features:
# * Native Multimodality: Built from the ground up to reason across different data types (text, images, video) simultaneously.
# * Real-Time Information: Deep integration with Google Search provides access to the most current information, avoiding a knowledge cut-off date.
# * Like all LLMs, it can **"hallucinate"** and generate inaccurate information.

# %% [markdown]
# ### 2.1 Code generation

# %% [markdown]
# You can use Gemini to directly generate code based on your natural language prompts as we already demonstrated in previous lectures. You could either copy and paste your generated code from other LLMs directly to code cells here OR you can directly generate code with Gemini by clicking `generate with AI` in the empty code cell to invoke Gemini. Alternatively, you could click the star-like icon (`Available AI features`) in the floating toolbar in the code cell and select `Generate code`
#
# * Try to ask Gemini to generate code to compute the number of seconds in a year by reusing the variable `seconds_in_a_day`.
#
# * You can also transform/modify the generated code using natural language by selecting the code snippet and click `Available AI features` in the floating toolbar - > `Transform code`.

# %% [markdown]
# ### 2.2 Code autocompletion

# %% [markdown]
# Python offers numerous built-in/external functions, but writing repetitive code or remembering specific function names and syntax can be challenging. Gemini's (and other LLMs') code autocompletion feature can streamline your coding process by suggesting completions for function names, variable names, and entire code snippets as you type in a cell. This intelligent assistance helps you write code more efficiently and with greater accuracy.
#
# To use this feature, you only need to click `tab` key on your keyboard to accept the automatically generated code (in gray). Give it a try below!
#
# ❗if you do not see the automatically generated code (in gray), try type in or delete some letters from the incomplete variable `seconds_i` and wait few seconds, then you will see the generated code.

# %%
seconds_in_a_week = 7 * seconds_i

# %% [markdown]
# ### 2.3 Code explanation

# %% [markdown]
# Of course, you can use Gemini to explain the logic and meaning of complex code to you in the Colab. So even with a beginner knowledge about Python (or other programming language), you should still be able to understand what the code does and modify the code per your need.
#
# To generate code explanation in Colab, select code snippet you want to understand in the code cell, then click the star-like icon (`Available AI features`) in the floating toolbar, select `Explain code`

# %%
def calculate_grade_average(student_name, scores):

    total_points = 0
    for score in scores:
        total_points += score

    average = total_points / len(scores)

    return {
        'student': student_name,
        'average': average
    }

alex_scores = [85, 92, 78, 88, 94]
alex_results = calculate_grade_average("Alex", alex_scores)

print(f"Student: {alex_results['student']}")
print(f"Average: {alex_results['average']:.1f}%")

# %% [markdown]
# ### 2.4 Code debugging

# %% [markdown]
# One of the most useful functions of the LLM is to debug the code which typically accounts for the majority of the time spent during the code development. For complex debugging task that involves large number of code and files, agentic AI is well suited for that task (review demonstration of agentic AI in previous lectures).
#
# Here, standard LLM (Gemini) should suffice our need. Below, there is a broken code snippet. Try to run the code cell first, and then ask Gemini to explain the error by simply clicking `Explain error` button. The Gemini (as of Aug 2025) will automatically suggest a solution to fix the code. You can `Accept` or `Reject` Gemini's suggestion, or suggest more changes using natural language prompts.

# %%
seconds_in_a_week = 7 * seconds_i
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3518006857.py in <cell line: 0>()
# ----> 1 seconds_in_a_week = 7 * seconds_i
#
# NameError: name 'seconds_i' is not defined

# %% [markdown]
# ✅ Feel free to use Gemini (or other LLMs) throughout the semester to help you with the Python coding!

# %% [markdown]
# ## 3. Python programming basics 🐍

# %% [markdown]
# Python is one of the most popular programming languages for machine learning, both in academia and in industry. As such, it is essential to learn this language for anyone interested in machine learning. In this section, we will review Python basics.

# %% [markdown]
# ### 3.1 Arithmetic operations

# %% [markdown]
# Python supports the usual arithmetic operators: + (addition), * (multiplication), / (division), ** (power), // (integer division).

# %% [markdown]
# ### 3.2 Lists

# %% [markdown]
# Lists are a container type for ordered sequences of elements. Lists can be initialized empty

# %%
my_list = []

# %% [markdown]
# or with some initial elements

# %%
my_list = [1, 2, 3]

# %% [markdown]
# Lists have a dynamic size and elements can be added (appended) to them

# %%
my_list.append(4)
my_list
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# We can access individual elements of a list (indexing starts from 0)

# %%
my_list[2]
# Out:
# 3

# %% [markdown]
# We can access "slices" of a list using `my_list[i:j]` where `i` is the start of the slice (again, indexing starts from 0) and `j` the end of the slice. For instance:

# %%
my_list[1:3]
# Out:
# [2, 3]

# %% [markdown]
# Omitting the second index means that the slice shoud run until the end of the list

# %%
my_list[1:]
# Out:
# [2, 3, 4]

# %% [markdown]
# We can check if an element is in the list using `in`

# %%
5 in my_list
# Out:
# False

# %% [markdown]
# The length of a list can be obtained using the `len` function

# %%
len(my_list)
# Out:
# 4

# %% [markdown]
# ### 3.3 Strings

# %% [markdown]
# Strings are used to store text. They can be defined using either single quotes or double quotes

# %%
string1 = "some text"
string2 = 'some other text'

# %% [markdown]
# Strings behave similarly to lists. As such we can access individual elements in exactly the same way

# %%
string1[3]
# Out:
# 'e'

# %% [markdown]
# and similarly for slices

# %%
string1[5:]
# Out:
# 'text'

# %% [markdown]
# String concatenation is performed using the `+` operator

# %%
string1 + " " + string2
# Out:
# 'some text some other text'

# %% [markdown]
# ### 3.4 Conditionals

# %% [markdown]
# As their name indicates, conditionals are a way to execute code depending on whether a condition is True or False. As in other languages, Python supports `if` and `else` but `else if` is contracted into `elif`, as the example below demonstrates.

# %%
my_variable = 5
if my_variable < 0:
  print("negative")
elif my_variable == 0:
  print("null")
else: # my_variable > 0
  print("positive")
# Out:
# positive

# %% [markdown]
# Here `<` and `>` are the strict `less` and `greater than` operators, while `==` is the equality operator (not to be confused with `=`, the variable assignment operator). The operators `<=` and `>=` can be used for less (resp. greater) than or equal comparisons.

# %% [markdown]
# Contrary to other languages, blocks of code are delimited using indentation. Here, we use 2-space indentation but many programmers also use 4-space indentation. Any one is fine as long as you are consistent throughout your code. An Integrated Development Environment (IDE), including Google Colab, will automatically add indentation for you, so you do not need to worry about it most of time.

# %% [markdown]
# ### 3.5 Loops

# %% [markdown]
# Loops are a way to execute a block of code multiple times. There are two main types of loops: **while** loops and **for** loops.

# %% [markdown]
# While loop

# %%
i = 0
while i < len(my_list):
  print(my_list[i])
  i += 1 # equivalent to i = i + 1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# For loop

# %%
for i in range(len(my_list)):
  print(my_list[i])
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# If the goal is simply to iterate over a list, we can do so directly as follows

# %%
for element in my_list:
  print(element)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ### 3.6 Functions

# %% [markdown]
# To improve code readability, it is common to separate the code into different blocks, responsible for performing precise actions: functions! 😃 A function takes some inputs and process them to return some outputs.

# %%
def square(x):
  return x ** 2

def multiply(a, b):
  return a * b

# Functions can be composed.
square(multiply(3, 2))
# Out:
# 36

# %% [markdown]
# You can also set the default value for input variables in a function:

# %%
# Default value set to 3
def square(x=3):
  return x ** 2

# without specifying x value, it will use the default value
print(square())

# of course, you can overwrite the default value
print(square(10))
# Out:
# 9
# 100

# %% [markdown]
# To improve code readability and avoid misalignment (i.e., unintended assignment of argument values due to relying solely on positional order), it is sometimes useful to explicitly name the arguments

# %%
square(multiply(a=3, b=2))
# Out:
# 36

# %% [markdown]
# ### 3.7 Exercise - conditionals, loops and function ❗❗

# %% [markdown]
# **Exercise 1.** Using a conditional, write the [relu](https://en.wikipedia.org/wiki/Rectifier_(neural_networks)) function defined as follows
#
# $\text{relu}(x) = \left\{
#    \begin{array}{rl}
#      x, & \text{if }  x \ge 0 \\
#      0, & \text{otherwise }.
#    \end{array}\right.$

# %%
def relu(x):
  # Write your function here
  return

relu(-3)

# %% [markdown]
# **Exercise 2.** Using a foor loop, write a function that computes the [Euclidean norm](https://en.wikipedia.org/wiki/Norm_(mathematics)#Euclidean_norm) of a vector, represented as a list.

# %%
def euclidean_norm(vector):
  # Write your function here
  return

my_vector = [0.5, -1.2, 3.3, 4.5]
# The result should be roughly 5.729746940310715
euclidean_norm(my_vector)

# %% [markdown]
# **Exercise 3.** Using a for loop and a conditional, write a function that returns the maximum value in a vector.

# %%
def vector_maximum(vector):
  # Write your function here
  return

# %% [markdown]
# **Bonus exercise.** if time permits, write a function that sorts a list in ascending order (from smaller to bigger) using the [bubble sort](https://en.wikipedia.org/wiki/Bubble_sort) algorithm.

# %% [markdown]
# Animation illustrating the bubble sort algorithm [ref](https://visual-sort-pink.vercel.app/Algorithm/Bubble.html):
#
# ![image.png](data:image/png;base64,...)

# %%
def bubble_sort(my_list):
  # Write your function here
  return

my_list = [1, -3, 3, 2]
# Should return [-3, 1, 2, 3]
bubble_sort(my_list)

# %% [markdown]
# ### 3.8 Going further 💯

# %% [markdown]
# Clearly, it is impossible to cover all the language features in this short introduction. To go further, we recommend the following resources:

# %% [markdown]
# *   Python for for computations in science and engineering [booklets](https://pointbreezepubs.gumroad.com/).
# *   List of Python [tutorials](https://wiki.python.org/moin/BeginnersGuide/Programmers)
# * Four-hour [course](https://www.youtube.com/watch?v=rfscVS0vtbw) on Youtube

# %% [markdown]
# ## 4. Python libraries 📖

# %% [markdown]
# Python by itself is a powerful language, but its true strength comes from its librarie, i.e., pre-built collections of functions and tools, that save you time and effort. Instead of reinventing the wheel, libraries allow you to quickly apply advanced methods for data analysis, visualization, machine learning, and scientific computing. Large open-source communities ensure continuous improvement and plenty of learning resources. There are over 670,000 libraries [as of August 2025](https://pypi.org/).
#
# In this section, we are going to introduce two important packages for scientific computing, NumPy and Matplotlib. We will introduce more packages as we progress through the semester.

# %% [markdown]
# ### 4.1 NumPy 💻

# %% [markdown]
# [NumPy](https://numpy.org/) is a popular library for storing arrays of numbers and performing computations on them. Not only this enables to write often more succint code, this also makes the code faster, since most NumPy routines are implemented in C for speed.

# %% [markdown]
# To use NumPy in your program, you need to import it as follows

# %%
import numpy as np

# %% [markdown]
# #### 4.1.1 Array creation

# %% [markdown]
# NumPy arrays can be created from Python lists

# %%
my_array = np.array([1, 2, 3])
my_array
# Out:
# array([1, 2, 3])

# %% [markdown]
# NumPy supports array of arbitrary dimension. For example, we can create two-dimensional arrays (e.g. to store a matrix) as follows

# %%
my_2d_array = np.array([[1, 2, 3], [4, 5, 6]])
my_2d_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# We can access individual elements of a 2d-array using two indices

# %%
my_2d_array[1, 2]
# Out:
# 6

# %% [markdown]
# We can also access rows

# %%
my_2d_array[1]
# Out:
# array([4, 5, 6])

# %% [markdown]
# and columns

# %%
my_2d_array[:, 2]
# Out:
# array([3, 6])

# %% [markdown]
# Arrays have a `shape` attribute

# %%
print(my_array.shape)
print(my_2d_array.shape)
# Out:
# (3,)
# (2, 3)

# %% [markdown]
# Contrary to Python lists, NumPy arrays must have a type and all elements of the array must have the same type.

# %%
my_array.dtype
# Out:
# dtype('int32')

# %% [markdown]
# The main types are `int32` (32-bit integers), `int64` (64-bit integers), `float32` (32-bit real values) and `float64` (64-bit real values).
#
# *Note: You can think of 32-bit or 64-bit as the memory that computer uses to store the number.*

# %% [markdown]
# The `dtype` can be specified when creating the array

# %%
my_array = np.array([1, 2, 3], dtype=np.float64)
my_array.dtype
# Out:
# dtype('float64')

# %% [markdown]
# We can create arrays of all zeros using

# %%
zero_array = np.zeros((2, 3))
zero_array
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %% [markdown]
# and similarly for all ones using `ones` instead of `zeros`.

# %% [markdown]
# We can create a range of values using

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# or specifying the starting point

# %%
np.arange(3, 5)
# Out:
# array([3, 4])

# %% [markdown]
# Another useful routine is `linspace` for creating linearly spaced values in an interval. For instance, to create 10 values in `[0, 1]`, we can use

# %%
np.linspace(0, 1, 10)
# Out:
# array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])

# %% [markdown]
# Another important operation is `reshape`, for changing the shape of an array

# %%
my_array = np.array([1, 2, 3, 4, 5, 6])
my_array.reshape(3, 2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %% [markdown]
# Play with these operations and make sure you understand them well.

# %% [markdown]
# #### 4.1.2 Basic operations

# %% [markdown]
# In NumPy, we express computations directly over arrays. This makes the code much more succint.

# %% [markdown]
# Arithmetic operations can be performed directly over arrays. For instance, assuming two arrays have a compatible shape, we can add them as follows

# %%
array_a = np.array([1, 2, 3])
array_b = np.array([4, 5, 6])
array_a + array_b
# Out:
# array([5, 7, 9])

# %% [markdown]
# Compare this with the equivalent computation using a for loop

# %%
array_out = np.zeros_like(array_a)
for i in range(len(array_a)):
  array_out[i] = array_a[i] + array_b[i]
array_out
# Out:
# array([5, 7, 9])

# %% [markdown]
# Not only this code is more verbose, it will also run much more slowly.

# %% [markdown]
# In NumPy, functions that operates on arrays in an element-wise fashion are called [universal functions](https://numpy.org/doc/stable/reference/ufuncs.html). For instance, this is the case of `np.sin`

# %%
np.sin(array_a)
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %% [markdown]
# Vector inner product can be performed using `np.dot`

# %%
np.dot(array_a, array_b)
# Out:
# 32

# %% [markdown]
# When the two arguments to `np.dot` are both 2d arrays, `np.dot` becomes matrix multiplication

# %%
array_A = np.random.rand(5, 3)
array_B = np.random.randn(3, 4)
np.dot(array_A, array_B)
# Out:
# array([[-0.78372786, -0.849849  , -0.80062414, -0.17832529],
#        [-0.95976823, -1.81073509, -0.58237139, -1.02972195],
#        [-1.00018451, -1.01810406, -1.04100908, -0.2526472 ],
#        [-0.73005882, -1.58872211, -0.40764567, -0.54033096],
#        [-0.46429466, -1.14327928, -0.12796835, -0.87775792]])

# %% [markdown]
# Matrix transpose can be done using `.transpose()` or `.T` for short

# %%
array_A.T
# Out:
# array([[0.53487215, 0.9167603 , 0.61587894, 0.98524764, 0.48891708],
#        [0.55500459, 0.73120862, 0.72928845, 0.44575498, 0.39782748],
#        [0.05074806, 0.68669673, 0.14052154, 0.05889541, 0.68256372]])

# %% [markdown]
# #### 4.1.3 Slicing and masking

# %% [markdown]
# Like Python lists, NumPy arrays support slicing

# %%
np.arange(10)[5:]
# Out:
# array([5, 6, 7, 8, 9])

# %% [markdown]
# We can also select only certain elements from the array

# %%
x = np.arange(10)
mask = x >= 5
x[mask]
# Out:
# array([5, 6, 7, 8, 9])

# %% [markdown]
# #### 4.1.4 Read and write files

# %% [markdown]
# In data science and engineering, we often need to save results (e.g., simulation data, experimental results) and read them back later. NumPy provides a convenient way to handle this. NumPy can work with common file types such as `.txt` and `.CSV`. For other file types (e.g., `.xlsx`), you can find other Python package to handle them.
#
# Let's see some examples.

# %%
# create and save data to txt file

data = np.array([1, 2, 3, 4, 5])

# Save array to a text file
np.savetxt("my_data.txt", data)

# %% [markdown]
# Files saved within a Google Colab notebook during a session are stored in the Colab Hosted VM (Virtual Machine). This VM is a temporary environment that runs your Jupyter notebook. You can view your saved file (`my_data.txt`) by clicking `Files` icon on the left hand-side toolbar. Now the Gemini can read and work with your saved data file.
#
# ❗ **Note**: This is a temporary space. Once the runtime disconnects or restarts, these files will be lost. So save your file in Google Drive or download it to your local machine if you want to keep the file.
#
# If you want to work with an existing file, you only need to upload that file to the VM workspace (by simple drag-and-drop).

# %%
# Read my_data.txt into an array
loaded_data = np.loadtxt("my_data.txt")

print("Loaded data:", loaded_data)
print("Type:", type(loaded_data))
# Out:
# Loaded data: [1. 2. 3. 4. 5.]
# Type: <class 'numpy.ndarray'>

# %% [markdown]
# #### 4.1.5 Exercise - arrays and linear algebra ❗❗

# %% [markdown]
# **Exercise 1.** Create a 3d array of shape (2, 2, 2), containing 8 values. Access individual elements and slices.

# %%
# Your code here

# %% [markdown]
# **Exercise 2.** Rewrite the relu function (see Python section) using [np.maximum](https://numpy.org/doc/stable/reference/generated/numpy.maximum.html). Check that it works on both a single value and on an array of values.

# %%
def relu_numpy(x):
  return #Your code here

relu_numpy(np.array([1, -3, 2.5]))

# %% [markdown]
# **Exercise 3.** Rewrite the Euclidean norm of a vector (1d array) using NumPy (without for loop)

# %%
def euclidean_norm_numpy(x):
  return

my_vector = np.array([0.5, -1.2, 3.3, 4.5])
euclidean_norm_numpy(my_vector)
# The result should be roughly 5.729746940310715

# %% [markdown]
# **Exercise 4.** Compute the mean value of the features in the california housing dataset. Hint: use the `axis` argument on [np.mean](https://numpy.org/doc/stable/reference/generated/numpy.mean.html).

# %%
# load california_housing_train.csv file under sample_data folder in colab space
data = np.loadtxt("sample_data/california_housing_train.csv", delimiter=",", skiprows=1)

# Your code here

# Result should be an array of size 9.

# %% [markdown]
# #### 4.1.6 Going further 💯

# %% [markdown]
# * NumPy [reference](https://numpy.org/doc/stable/reference/)
# * SciPy [lectures](https://scipy-lectures.org/)
# *   One-hour [tutorial](https://www.youtube.com/watch?v=QUT1VHiLmmI) on Youtube

# %% [markdown]
# ### 4.2 Matplotlib 📈

# %% [markdown]
# Matplotlib is a plotting library for Python. There are many other plotting libraries you can try after class:
#
#
# [Seaborn](https://seaborn.pydata.org/):
#
#
# * Built on top of Matplotlib, but with much nicer default styles.
# * Specializes in statistical data visualization (correlation heatmaps, regression plots, violin plots).
# * Great for quick insights into data distributions and relationships.
#
# [Plotly](https://plotly.com/):
# * Interactive plots out-of-the-box (zoom, hover tooltips, sliders).
# * Can export to HTML dashboards.
# * Great for exploratory data analysis and web applications.

# %% [markdown]
# #### 4.2.1 Basic plots

# %% [markdown]
# We start with a rudimentary plotting example.

# %%
from matplotlib import pyplot as plt

x_values = np.linspace(-3, 3, 100)

plt.figure()
plt.plot(x_values, np.sin(x_values), label="Sinusoid")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Matplotlib example")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# We continue with a rudimentary scatter plot example. This example displays samples from the California housing dataset using two features (longitude and latitude). Colors indicate median house value.

# %%
data = np.loadtxt("sample_data/california_housing_train.csv", delimiter=",", skiprows=1)

plt.figure()
scatter = plt.scatter(data[:, 0], data[:, 1], c=data[:, 8], cmap='viridis', alpha=0.6)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Scatter Plot of Longitude vs. Latitude (California Housing)")
plt.colorbar(scatter, label='Median House Value') # Add a color bar
plt.grid(True)
plt.show()

# %% [markdown]
# #### 4.2.2 Exercise - plots ❗❗

# %% [markdown]
# **Exercise 1.** Plot the relu and the [softplus](https://en.wikipedia.org/wiki/Rectifier_(neural_networks)#Softplus) functions on the same graph.
#
# Softplus function:
# $$
# f(x) = \ln(1+e^x)
# $$

# %%
# Your code here

# %% [markdown]
# What is the main difference between the two functions?

# %% [markdown]
# #### 4.2.3 Going further 💯
#
# *  Official [tutorial](https://matplotlib.org/tutorials/introductory/pyplot.html)
# * [Tutorial](https://www.youtube.com/watch?v=qErBw-R2Ybk) on Youtube
